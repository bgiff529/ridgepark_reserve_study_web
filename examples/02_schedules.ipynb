# %% [markdown]
# # Components and Schedules
#
# Inspect components, the generated expenditure schedule, and the collection schedule.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "reserve_study").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from reserve_study import ReserveStudy

study = ReserveStudy.from_directory("2026_brendan_plan")
result = study.run(projection_years=30)
scenario = study.scenario

# %%
components = result.component_details_df()
components[["component_id", "category", "component", "current_cost", "replacement_date", "future_cost"]].head(10)

# %%
result.expenditure_schedule.detail_df().head(10)

# %%
result.collection_schedule.annual_df().head(10)

# %%
dated_collections = result.collection_schedule.dated_events(
    start_year=scenario.assumptions.analysis_year,
    projection_years=1,
)
[(event.date, event.event_type, event.amount) for event in dated_collections[:14]]
