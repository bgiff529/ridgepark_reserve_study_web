# %% [markdown]
# # Reports and Plots
#
# Generate the CSV outputs, plots, TeX report, and PDF when a local TeX compiler is available.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "reserve_study").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from reserve_study import ReportBuilder, ReserveStudy

study = ReserveStudy.from_directory("30_year_RP_budget")
result = study.run(projection_years=30)
result.write_outputs()
result.scenario.paths.output_root
# Out:
# PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget')

# %%
plot_paths = result.build_plots()
plot_paths
# Out:
# [PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/reserve_contributions_over_time.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/expenditures_and_total_contributions.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/annual_and_cumulative_expenditures_vs_contributions.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/annual_and_cumulative_reserve_contributions.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/annual_and_cumulative_contributions_and_expenditures.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/reserve_balance.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/contributions_detail.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/expenditures_vs_contributions_detail.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/reserve_balance_vs_fully_funded.pdf'),
#  PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/plots/percent_funded.pdf')]

# %%
tex_path = result.build_report()
tex_path
# Out:
# PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/report_latex/ridge_park_reserve_report_latex.tex')

# %%
if ReportBuilder.find_pdf_compiler() is None:
    print("No latexmk or pdflatex found. Install MacTeX or add a TeX compiler to PATH to build the PDF.")
    pdf_path = None
else:
    pdf_path = result.build_report(compile_pdf=True)
pdf_path
# Out:
# PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/report_latex/ridge_park_reserve_report_latex.pdf')
