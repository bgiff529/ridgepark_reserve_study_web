# %% [markdown]
# # Run a Reserve Study
#
# Load a local scenario, run the study, and inspect the main output tables.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "reserve_study").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from reserve_study import ReserveStudy

variant = "30_year_RP_budget"
study = ReserveStudy.from_directory(variant)
result = study.run(projection_years=30)
scenario = study.scenario

scenario.assumptions
# Out:
# Assumptions(analysis_date=Timestamp('2026-01-01 00:00:00'), inflation=0.03, investment=0.025, contribution_factor=0.0, begin_balance=607915.91)

# %%
result.statement_of_position_formatted_df()
# Out:
#                                            metric   formatted
# 0                        Current Replacement Cost  $4,790,206
# 1                         Future Replacement Cost  $7,182,686
# 2                    Current Reserve Fund Balance    $607,916
# 3                    Fully Funded Reserve Balance  $2,768,170
# 4                                  Percent Funded     21.96 %
# 5                                 Reserve Deficit  $2,160,254
# 6                        Reserve Deficit per Unit     $15,654
# 7           Projected Annual Reserve Contribution    $221,333
# 8    Average Annual Reserve Contribution per Unit      $1,604
# 9          Projected Monthly Reserve Contribution     $18,444
# 10  Average Monthly Reserve Contribution per Unit        $134

# %%
result.reserve_projection_df().head()
# Out:
#    year  begin_balance  contribution  special_assessment  expenditures  \
# 0  2026      607915.91     221333.23                 0.0     648525.03
# 1  2027      193567.72     203263.75                 0.0     276536.20
# 2  2028      124470.47     267549.50                 0.0     179370.75
# 3  2029      216886.04     165530.13                 0.0      22538.38
# 4  2030      367315.94     146506.90                 0.0      23606.17
#
#    interest  end_balance  funded_balance  percent_funded
# 0  12843.61    193567.72      2349278.09            8.24
# 1   4175.21    124470.47      2279741.30            5.46
# 2   4236.81    216886.04      2302902.58            9.42
# 3   7438.16    367315.94      2488121.64           14.76
# 4  11041.11    501257.78      2681372.53           18.69

# %%
result.write_outputs()
result.scenario.paths.working_csv_dir
# Out:
# PosixPath('/Users/bgifford/Documents/HOA/Ridge Park Reserve Study OO/runs/30_year_RP_budget/working_csv')
